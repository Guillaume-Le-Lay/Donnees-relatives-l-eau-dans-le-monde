# %% [markdown]
# # Sommaire :
# - <a href="#C1">Import des librairies</a>
# - <a href="#C2">Import des données</a>
# - <a href="#C3">Lecture des données & suppression granularités inutiles</a>
# - <a href="#C4">Correspondance WaterServices et Mortality</a>
# - <a href="#C5">Correspondance df et PoliticalStability</a>
# - <a href="#C6">Correspondance df & Population</a>
# - <a href="#C7">Correspondance df & RegionCountry</a>
# - <a href="#C8">Fusion des datasets après nettoyage</a>
#     - <a href="#C9"> Fusion WaterServices & Mortality </a>
#     - <a href="#C10"> Fusion df & Political Stability </a>
#     - <a href="#C11"> Fusion df1 & Population </a>
#     - <a href="#C12"> Fusion df2 & Population </a>
# - <a href="#C14.2">Ajout de la colonne Urban population rate</a>
# - <a href="#C14.5"> Ajout des densités de Population </a>
#     - <a href="#C14.51"> Ajout des densités de Population par Pays</a>
#     - <a href="#C14.52"> Ajout des densités de Population par Région</a>
#     - <a href="#C14.53"> Ajout de la densité de Population niveau Monde</a>
# - <a href="#C15"> Export du .csv </a>

# %% [markdown]
# # <a name="C1"> Import des librairies </a>

# %%
import pandas as pd
pd.options.display.max_columns = None # pour afficher toutes les colonnes
pd.options.display.max_rows = None # pour afficher toutes les lignes

import numpy as np

from scipy import stats

from datetime import datetime

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker

import seaborn as sns

import statsmodels.api as sm
import pylab

# %% [markdown]
# # <a name="C2"> Import des données </a>

# %% [markdown]
# Données d'OpenClassrooms et de la Banque mondiale pour les surfaces des pays

# %%
Population = pd.read_csv('Population.csv')
BasicAndSafelyManagedDrinkingWaterServices = pd.read_csv('BasicAndSafelyManagedDrinkingWaterServices.csv')
PoliticalStability = pd.read_csv('PoliticalStability.csv')
MortalityRateAttributedToWater = pd.read_csv('MortalityRateAttributedToWater.csv')
RegionCountry = pd.read_csv('RegionCountry.csv')

# %% [markdown]
# # <a name="C3"> Lecture des données & suppression granularités inutiles </a>

# %% [markdown]
# ## BasicAndSafelyManagedDrinkingWaterServices

# %%
BasicAndSafelyManagedDrinkingWaterServices.head()
# Out:
#    Year      Country Granularity  \
# 0  2000  Afghanistan       Rural
# 1  2000  Afghanistan       Total
# 2  2000  Afghanistan       Urban
# 3  2000      Albania       Rural
# 4  2000      Albania       Total
#
#    Population using at least basic drinking-water services (%)  \
# 0                                           21.61913
# 1                                           27.77190
# 2                                           49.48745
# 3                                           81.78472
# 4                                           87.86662
#
#    Population using safely managed drinking-water services (%)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           49.29324

# %%
len(BasicAndSafelyManagedDrinkingWaterServices)
# Out:
# 10476

# %%
BasicAndSafelyManagedDrinkingWaterServices['Granularity'].value_counts()
# Out:
# Urban    3492
# Rural    3492
# Total    3492
# Name: Granularity, dtype: int64

# %% [markdown]
# ## MortalityRateAttributedToWater

# %%
MortalityRateAttributedToWater.head()
# Out:
#    Year      Country Granularity  \
# 0  2016  Afghanistan      Female
# 1  2016  Afghanistan        Male
# 2  2016  Afghanistan       Total
# 3  2016      Albania      Female
# 4  2016      Albania        Male
#
#    Mortality rate attributed to exposure to unsafe WASH services  WASH deaths
# 0                                           15.31193                      NaN
# 1                                           12.61297                      NaN
# 2                                           13.92067                 4824.353
# 3                                            0.12552                      NaN
# 4                                            0.20650                      NaN

# %%
len(MortalityRateAttributedToWater)
# Out:
# 549

# %%
MortalityRateAttributedToWater['Granularity'].value_counts()
# Out:
# Total     183
# Male      183
# Female    183
# Name: Granularity, dtype: int64

# %% [markdown]
# Suppression des granularités Male/Female :

# %%
MortalityRateAttributedToWater.drop\
(MortalityRateAttributedToWater[MortalityRateAttributedToWater['Granularity'] == 'Male'].index,\
 inplace=True)
MortalityRateAttributedToWater.drop\
(MortalityRateAttributedToWater[MortalityRateAttributedToWater['Granularity'] == 'Female'].index,\
 inplace=True)

MortalityRateAttributedToWater['Granularity'].value_counts() # vérification
# Out:
# Total    183
# Name: Granularity, dtype: int64

# %% [markdown]
# ## PoliticalStability

# %%
PoliticalStability.head()
# Out:
#        Country  Year  Political_Stability Granularity
# 0  Afghanistan  2000                -2.44       Total
# 1  Afghanistan  2002                -2.04       Total
# 2  Afghanistan  2003                -2.20       Total
# 3  Afghanistan  2004                -2.30       Total
# 4  Afghanistan  2005                -2.07       Total

# %%
len(PoliticalStability)
# Out:
# 3526

# %%
PoliticalStability['Granularity'].value_counts()
# Out:
# Total    3526
# Name: Granularity, dtype: int64

# %% [markdown]
# ## Population

# %%
Population.head()
# Out:
#        Country Granularity  Year  Population
# 0  Afghanistan       Total  2000   20779.953
# 1  Afghanistan        Male  2000   10689.508
# 2  Afghanistan      Female  2000   10090.449
# 3  Afghanistan       Rural  2000   15657.474
# 4  Afghanistan       Urban  2000    4436.282

# %%
len(Population)
# Out:
# 20914

# %%
Population['Granularity'].value_counts()
# Out:
# Total     4430
# Urban     4414
# Rural     4414
# Male      3828
# Female    3828
# Name: Granularity, dtype: int64

# %% [markdown]
# Suppression des granularités Male/Female :

# %%
Population.drop\
(Population[Population['Granularity'] == 'Male'].index,inplace=True)
Population.drop\
(Population[Population['Granularity'] == 'Female'].index,inplace=True)

Population['Granularity'].value_counts() # vérification
# Out:
# Total    4430
# Urban    4414
# Rural    4414
# Name: Granularity, dtype: int64

# %% [markdown]
# ## RegionCountry

# %%
RegionCountry.head()
# Out:
#   REGION (DISPLAY) COUNTRY (DISPLAY)
# 0           Europe           Albania
# 1           Europe           Andorra
# 2           Europe           Armenia
# 3  Western Pacific         Australia
# 4           Europe           Austria

# %%
len(RegionCountry)
# Out:
# 194

# %%
RegionCountry['REGION (DISPLAY)'].value_counts()
# Out:
# Europe                   53
# Africa                   47
# Americas                 35
# Western Pacific          27
# Eastern Mediterranean    21
# South-East Asia          11
# Name: REGION (DISPLAY), dtype: int64

# %% [markdown]
# ### Changements RegionDisplay

# %%
# Pays dans Eastern Meditteranean placés en Afrique
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Morocco', 'Africa' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Tunisia', 'Africa' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Egypt', 'Africa' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Lybia', 'Africa' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Somalia', 'Africa' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Sudan', 'Africa' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Libya', 'Africa' , inplace=True)
# Pays dans Eastern Meditteranean placés en Asie
RegionCountry.loc[RegionCountry['REGION (DISPLAY)'] =='Eastern Mediterranean','REGION (DISPLAY)'] ='Asia'
# Pays dans South-East Asia placés en Asie
RegionCountry.loc[RegionCountry['REGION (DISPLAY)'] =='South-East Asia','REGION (DISPLAY)'] ='Asia'
# Pays dans Western Pacific placés en Océanie
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Australia','Oceania',inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Fiji', 'Oceania',inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Papua New Guinea','Oceania', inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Fiji', 'Oceania' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Solomon Islands', 'Oceania' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Marshall Islands', 'Oceania' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Micronesia (Federated States of)', 'Oceania' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'New Zealand', 'Oceania' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Vanuatu', 'Oceania' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Samoa', 'Oceania' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Palau', 'Oceania' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Kiribati', 'Oceania' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Tuvalu', 'Oceania' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Nauru', 'Oceania' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Tonga', 'Oceania' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Cook Islands', 'Oceania' , inplace=True)
RegionCountry['REGION (DISPLAY)'].mask(RegionCountry['COUNTRY (DISPLAY)'] == 'Niue', 'Oceania' , inplace=True)
# Pays dans Western Pacific placés en Asie
RegionCountry.loc[RegionCountry['REGION (DISPLAY)'] =='Western Pacific','REGION (DISPLAY)'] ='Asia'

# %%
RegionCountry[RegionCountry['REGION (DISPLAY)']=='Asia']
# Out:
#     REGION (DISPLAY)                      COUNTRY (DISPLAY)
# 6               Asia                                Bahrain
# 7               Asia                             Bangladesh
# 10              Asia                                 Bhutan
# 15              Asia                               Cambodia
# 18              Asia                                  China
# 26              Asia  Democratic People's Republic of Korea
# 45              Asia                                  India
# 46              Asia             Iran (Islamic Republic of)
# 47              Asia                                   Iraq
# 51              Asia                                  Japan
# 52              Asia                                 Jordan
# 55              Asia                                 Kuwait
# 57              Asia       Lao People's Democratic Republic
# 59              Asia                                Lebanon
# 62              Asia                               Malaysia
# 66              Asia                               Mongolia
# 69              Asia                                  Nepal
# 77              Asia                                   Oman
# 78              Asia                               Pakistan
# 81              Asia                            Philippines
# 84              Asia                                  Qatar
# 85              Asia                      Republic of Korea
# 94              Asia                              Singapore
# 99              Asia                              Sri Lanka
# 115             Asia                            Afghanistan
# 125             Asia                      Brunei Darussalam
# 136             Asia                               Djibouti
# 148             Asia                              Indonesia
# 156             Asia                               Maldives
# 163             Asia                                Myanmar
# 174             Asia                           Saudi Arabia
# 182             Asia                   Syrian Arab Republic
# 183             Asia                               Thailand
# 184             Asia                            Timor-Leste
# 189             Asia                   United Arab Emirates
# 191             Asia                               Viet Nam
# 192             Asia                                  Yemen

# %%
RegionCountry['REGION (DISPLAY)'].value_counts()
# Out:
# Africa      53
# Europe      53
# Asia        37
# Americas    35
# Oceania     16
# Name: REGION (DISPLAY), dtype: int64

# %% [markdown]
# # <a name="C4"> Correspondance WaterServices & Mortality </a>

# %% [markdown]
# Fusion des datasets sur le pays :

# %%
df = BasicAndSafelyManagedDrinkingWaterServices.merge(MortalityRateAttributedToWater,
                                                      how='outer',
                                                      on='Country',
                                                      indicator=True)

# %% [markdown]
# Décomptes des lignes sans correspondance avec mention du dataset d'origine :

# %%
df._merge.value_counts()
# Out:
# both          9882
# left_only      594
# right_only       0
# Name: _merge, dtype: int64

# %% [markdown]
# Tous les pays de Mortality ont une correspondance dans WaterServices.
#
# Affichage des pays dans WaterServices sans correspondance dans Mortality :

# %%
left_only = df[df._merge == 'left_only']
left_only['Country'].value_counts()
# Out:
# Nauru                    54
# Cook Islands             54
# San Marino               54
# Monaco                   54
# Tuvalu                   54
# Marshall Islands         54
# Niue                     54
# Dominica                 54
# Palau                    54
# Saint Kitts and Nevis    54
# Andorra                  54
# Name: Country, dtype: int64

# %% [markdown]
# On ne dispose de données sur la mortalité pour ces pays.

# %% [markdown]
# Suppression de la colonne _merge :

# %%
df.drop(columns=['_merge'],inplace=True)

# %% [markdown]
# # <a name="C5"> Correspondance df & PoliticalStability </a>

# %% [markdown]
# Fusion des datasets sur le pays :

# %%
df = df.merge(PoliticalStability,
             how='outer',
             on='Country',
             indicator=True)

# %% [markdown]
# Décomptes des lignes sans correspondance :

# %%
df._merge.value_counts()
# Out:
# both          181278
# left_only        216
# right_only       169
# Name: _merge, dtype: int64

# %% [markdown]
# Pays dans df sans correspondance dans politicalStability :

# %%
left_only = df[df._merge == 'left_only']
left_only['Country'].value_counts()
# Out:
# San Marino                     54
# Republic of North Macedonia    54
# Monaco                         54
# China                          54
# Name: Country, dtype: int64

# %% [markdown]
# Pays dans PoliticalStability sans correspondance dans df :

# %%
right_only = df[df._merge == 'right_only']
right_only['Country'].value_counts()
# Out:
# Palestine                    18
# Bermuda                      18
# China, Taiwan Province of    18
# North Macedonia              18
# China, Macao SAR             18
# Puerto Rico                  18
# China, Hong Kong SAR         18
# China, mainland              18
# American Samoa               15
# Greenland                    10
# Name: Country, dtype: int64

# %% [markdown]
# ## Monaco, San Marino

# %% [markdown]
# Pas de données sur la stabilité politique.

# %% [markdown]
# ## Macédoine

# %% [markdown]
# changement du nom dans PoliticalStability pour établir la correspondance :

# %%
PoliticalStability.replace({'North Macedonia': 'Republic of North Macedonia'}, inplace=True)

# %% [markdown]
# Vérification :

# %%
PoliticalStability[PoliticalStability['Country'] == 'Republic of North Macedonia'].head()
# Out:
#                           Country  Year  Political_Stability Granularity
# 2320  Republic of North Macedonia  2000                -0.62       Total
# 2321  Republic of North Macedonia  2002                -1.04       Total
# 2322  Republic of North Macedonia  2003                -0.99       Total
# 2323  Republic of North Macedonia  2004                -0.85       Total
# 2324  Republic of North Macedonia  2005                -1.16       Total

# %% [markdown]
# ## Puerto Rico, Bermudes, American Samoa, Palestine & Groënland

# %% [markdown]
# Aires géographiques avec un indice de stabilité politique qui ne sont pas recensés dans les dataset donnant les indicateurs sur l'eau.
#
# Suppression des indicateurs de stabilité politique car ces aires géographiques prendront l'indicateur de stabilité politique de leurs pays d'appartenance.

# %%
PoliticalStability.drop(PoliticalStability[PoliticalStability['Country'] == 'Puerto Rico'].index,inplace=True)
PoliticalStability.drop(PoliticalStability[PoliticalStability['Country'] == 'Bermuda'].index,inplace=True)
PoliticalStability.drop(PoliticalStability[PoliticalStability['Country'] == 'American Samoa'].index,inplace=True)
PoliticalStability.drop(PoliticalStability[PoliticalStability['Country'] == 'Greenland'].index,inplace=True)
PoliticalStability.drop(PoliticalStability[PoliticalStability['Country'] == 'Palestine'].index,inplace=True)

# %% [markdown]
# Vérifications :

# %%
PoliticalStability[PoliticalStability['Country'] == 'Puerto Rico'].head()
# Out:
# Empty DataFrame
# Columns: [Country, Year, Political_Stability, Granularity]
# Index: []

# %%
PoliticalStability[PoliticalStability['Country'] == 'Bermuda'].head()
# Out:
# Empty DataFrame
# Columns: [Country, Year, Political_Stability, Granularity]
# Index: []

# %%
PoliticalStability[PoliticalStability['Country'] == 'American Samoa'].head()
# Out:
# Empty DataFrame
# Columns: [Country, Year, Political_Stability, Granularity]
# Index: []

# %%
PoliticalStability[PoliticalStability['Country'] == 'Greenland'].head()
# Out:
# Empty DataFrame
# Columns: [Country, Year, Political_Stability, Granularity]
# Index: []

# %%
PoliticalStability[PoliticalStability['Country'] == 'Palestine'].head()
# Out:
# Empty DataFrame
# Columns: [Country, Year, Political_Stability, Granularity]
# Index: []

# %% [markdown]
# ## Chine

# %% [markdown]
# Suppression de l'indicateur de stabilité politique pour Honk-Kong, Macao et Taïwan car on ne dispose pas de données spécifiques sur l'accès à l'eau pour ces régions chinoises alors que les indicateurs sur l'eau semblent concerner tout le territoire de la Chine ("China").
#
# On est donc obligés, en contrepartie, d'utiliser l'indicateur de stabilité politique de la Chine continentale pour ces zones.

# %% [markdown]
# ### Suppression pour Honk-Kong :

# %%
PoliticalStability.drop(PoliticalStability[PoliticalStability['Country'] == 'China, Hong Kong SAR'].index,inplace=True)

# %% [markdown]
# Vérification :

# %%
PoliticalStability[PoliticalStability['Country'] == 'China, Hong Kong SAR']
# Out:
# Empty DataFrame
# Columns: [Country, Year, Political_Stability, Granularity]
# Index: []

# %% [markdown]
# ### Suppression pour Macao :

# %%
PoliticalStability.drop(PoliticalStability[PoliticalStability['Country'] == 'China, Macao SAR'].index,inplace=True)

# %% [markdown]
# Vérification :

# %%
PoliticalStability[PoliticalStability['Country'] == 'China, Macao SAR']
# Out:
# Empty DataFrame
# Columns: [Country, Year, Political_Stability, Granularity]
# Index: []

# %% [markdown]
# ### Suppression pour Taïwan

# %%
PoliticalStability.drop(PoliticalStability[PoliticalStability['Country'] == 'China, Taiwan Province of'].index,inplace=True)

# %% [markdown]
# Vérification :

# %%
PoliticalStability[PoliticalStability['Country'] == 'China, Taiwan Province of']
# Out:
# Empty DataFrame
# Columns: [Country, Year, Political_Stability, Granularity]
# Index: []

# %% [markdown]
# ### changement du nom 'China, mainland' dans PoliticalStability en 'China' pour établir la correspondance :

# %%
PoliticalStability.replace({'China, mainland': 'China'}, inplace=True)

# %%
PoliticalStability[PoliticalStability['Country'] == 'China']
# Out:
#     Country  Year  Political_Stability Granularity
# 699   China  2000                -0.21       Total
# 700   China  2002                -0.33       Total
# 701   China  2003                -0.56       Total
# 702   China  2004                -0.39       Total
# 703   China  2005                -0.50       Total
# 704   China  2006                -0.54       Total
# 705   China  2007                -0.50       Total
# 706   China  2008                -0.49       Total
# 707   China  2009                -0.45       Total
# 708   China  2010                -0.66       Total
# 709   China  2011                -0.60       Total
# 710   China  2012                -0.54       Total
# 711   China  2013                -0.54       Total
# 712   China  2014                -0.52       Total
# 713   China  2015                -0.55       Total
# 714   China  2016                -0.50       Total
# 715   China  2017                -0.23       Total
# 716   China  2018                -0.26       Total

# %% [markdown]
# Suppression de la colonne merge :

# %%
df.drop(columns=['_merge'],inplace=True)

# %% [markdown]
# ## Vérification des modifications

# %% [markdown]
# Fusion de WaterServices et de Mortality :

# %%
df = BasicAndSafelyManagedDrinkingWaterServices.merge(MortalityRateAttributedToWater,
                                                      how='outer',
                                                      on='Country',
                                                      indicator=True)

# %% [markdown]
# Suppression de la colonne merge :

# %%
df.drop(columns=['_merge'],inplace=True)

# %% [markdown]
# Fusion de df et de PoliticalStability :

# %%
df = df.merge(PoliticalStability,
              how='outer',
              on='Country',
              indicator=True)

# %%
df['_merge'].value_counts()
# Out:
# both          183222
# left_only        108
# right_only         0
# Name: _merge, dtype: int64

# %% [markdown]
# Pays dans df sans correspondance dans politicalStability :

# %%
left_only = df[df._merge == 'left_only']
left_only['Country'].value_counts()
# Out:
# San Marino    54
# Monaco        54
# Name: Country, dtype: int64

# %% [markdown]
# Vérification validée : il ne reste que les pays où les indicateurs de mortalité sont manquants.

# %% [markdown]
# Suppression de la colonne merge :

# %%
df.drop(columns=['_merge'],inplace=True)

# %%
len(df)
# Out:
# 183330

# %% [markdown]
# # <a name="C6"> Correspondance df & Population </a>

# %% [markdown]
# Fusion des datasets sur le pays :

# %%
df = df.merge(Population,
             how='outer',
             on='Country',
             indicator=True)

# %% [markdown]
# Décomptes des lignes sans correspondance :

# %%
df._merge.value_counts()
# Out:
# both          10313730
# right_only        2365
# left_only          972
# Name: _merge, dtype: int64

# %% [markdown]
# Pays dans df sans correspondance dans Population :

# %%
left_only = df[df._merge == 'left_only']
left_only['Country'].value_counts()
# Out:
# Republic of North Macedonia    972
# Name: Country, dtype: int64

# %% [markdown]
# Pays dans Population sans correspondance dans df :

# %%
right_only = df[df._merge == 'right_only']
right_only = right_only['Country'].value_counts()
right_only
# Out:
# Greenland                                       57
# Montserrat                                      57
# China, mainland                                 57
# Guam                                            57
# Turks and Caicos Islands                        57
# United States Virgin Islands                    57
# Faroe Islands                                   57
# French Guyana                                   57
# Anguilla                                        57
# Isle of Man                                     57
# French Polynesia                                57
# Guadeloupe                                      57
# Palestine                                       57
# China, Macao SAR                                57
# Liechtenstein                                   57
# Saint Pierre and Miquelon                       57
# British Virgin Islands                          57
# Netherlands Antilles (former)                   57
# Cayman Islands                                  57
# American Samoa                                  57
# Mayotte                                         57
# Saint Helena, Ascension and Tristan da Cunha    57
# Gibraltar                                       57
# Falkland Islands (Malvinas)                     57
# Martinique                                      57
# New Caledonia                                   57
# Wallis and Futuna Islands                       57
# Holy See                                        57
# Bermuda                                         57
# Channel Islands                                 57
# Aruba                                           57
# Western Sahara                                  57
# Puerto Rico                                     57
# North Macedonia                                 57
# Réunion                                         57
# Northern Mariana Islands                        57
# China, Hong Kong SAR                            57
# China, Taiwan Province of                       57
# Tokelau                                         57
# Sudan (former)                                  36
# Curaçao                                         24
# Sint Maarten  (Dutch part)                      24
# Bonaire, Sint Eustatius and Saba                24
# Serbia and Montenegro                           18
# Saint Barthélemy                                 8
# Saint-Martin (French part)                       8
# Name: Country, dtype: int64

# %% [markdown]
# ## Macédoine

# %% [markdown]
# Changement du nom 'North Macedonia" en "Republic of North Macedonia" dans Population :

# %%
Population.replace({'North Macedonia': 'Republic of North Macedonia'}, inplace=True)

# %% [markdown]
# Vérification :

# %%
Population[Population['Country'] == 'Republic of North Macedonia'].head()
# Out:
#                            Country Granularity  Year  Population
# 13904  Republic of North Macedonia       Total  2000    2034.819
# 13907  Republic of North Macedonia       Rural  2000     843.475
# 13908  Republic of North Macedonia       Urban  2000    1191.344
# 13909  Republic of North Macedonia       Total  2001    2042.842
# 13912  Republic of North Macedonia       Rural  2001     851.059

# %% [markdown]
# ## Zones géographiques dans population

# %% [markdown]
# Ce sont des zones géographiques (pas des pays) dont on a indiqué la population.
#
# La question est de savoir si, dans la population des pays de rattachement, la population de ces zones géographiques ont été ajoutées.
#
# - Si oui : suppression des lignes dans Population
# - Si non : Ajout de la popualtion de ces lignes aux pays de rattachement.

# %% [markdown]
# 1er test sur la population de la Chine. Est-ce que l'entrée "China" prend en compte toute la population chinoise, avec Honk- Kong et Macao ?

# %%
Population[(Population['Country'] == 'China') & (Population['Year'] == 2018)]
# Out:
#      Country Granularity  Year   Population
# 3876   China       Total  2018  1459377.612
# 3879   China       Rural  2018   583199.631
# 3880   China       Urban  2018   863601.691

# %% [markdown]
# 1 459 377 612 habitants en 2018 selon l'entrée 'China' du datset Population.
# - 1 milliard 427 millions selon Worldometer
# - 1 milliard 403 millions selon la Banque Mondiale
#
# Conclusion : l'entrée China semble prendre en compte les populations de Honk-Kong et de Macao.

# %% [markdown]
# 2ème test sur la population du Royaume-Uni.

# %%
Population[(Population['Country'] == 'United Kingdom of Great Britain and Northern Ireland') \
           & (Population['Year'] == 2018)]
# Out:
#                                                  Country Granularity  Year  \
# 19712  United Kingdom of Great Britain and Northern I...       Total  2018
# 19715  United Kingdom of Great Britain and Northern I...       Rural  2018
# 19716  United Kingdom of Great Britain and Northern I...       Urban  2018
#
#        Population
# 19712   67141.684
# 19715   11052.278
# 19716   55521.226

# %% [markdown]
# 67 millions selon l'entrée Royaume-Uni du dataset Population.
# - 66,46 millions selon la Banque mondiale.
#
# Conclusion : l'entrée Royaume-Uni semble prendre en compte les aires géographiques mentionnées par ailleurs dans le dataset Population (Iles Vierges Britanniques par exemple).

# %% [markdown]
# Conclusion Générale : suppression des lignes du dataset Population sans correspondance dans dataset df.

# %% [markdown]
# ## Suppression des lignes dans Population

# %%
type(right_only)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Transformation de l'index de right_only en liste (contenant les noms des aires géographiques à supprimer) :

# %%
right_only = right_only.index.tolist()

# %% [markdown]
# Vérification :

# %%
type(right_only)
# Out:
# list

# %%
print(right_only)
# Out:
# ['Greenland', 'Montserrat', 'China, mainland', 'Guam', 'Turks and Caicos Islands', 'United States Virgin Islands', 'Faroe Islands', 'French Guyana', 'Anguilla', 'Isle of Man', 'French Polynesia', 'Guadeloupe', 'Palestine', 'China, Macao SAR', 'Liechtenstein', 'Saint Pierre and Miquelon', 'British Virgin Islands', 'Netherlands Antilles (former)', 'Cayman Islands', 'American Samoa', 'Mayotte', 'Saint Helena, Ascension and Tristan da Cunha', 'Gibraltar', 'Falkland Islands (Malvinas)', 'Martinique', 'New Caledonia', 'Wallis and Futuna Islands', 'Holy See', 'Bermuda', 'Channel Islands', 'Aruba', 'Western Sahara', 'Puerto Rico', 'North Macedonia', 'Réunion', 'Northern Mariana Islands', 'China, Hong Kong SAR', 'China, Taiwan Province of', 'Tokelau', 'Sudan (former)', 'Curaçao', 'Sint Maarten  (Dutch part)', 'Bonaire, Sint Eustatius and Saba', 'Serbia and Montenegro', 'Saint Barthélemy', 'Saint-Martin (French part)']

# %% [markdown]
# Suppression des entrées dans Population :

# %%
for i in right_only :
    Population.drop(Population[Population['Country'] == i].index,inplace=True)

# %% [markdown]
# Vérification :

# %%
for i in right_only :
    print(Population[Population['Country'] == i])
# Out:
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []
# Empty DataFrame
# Columns: [Country, Granularity, Year, Population]
# Index: []

# %% [markdown]
# Suppression de la colonne merge :

# %%
df.drop(columns=['_merge'],inplace=True)

# %% [markdown]
# ## Vérification des modifications :

# %% [markdown]
# Fusion de WaterServices et de Mortality :

# %%
df = BasicAndSafelyManagedDrinkingWaterServices.merge(MortalityRateAttributedToWater,
                                                      how='outer',
                                                      on='Country',
                                                      indicator=True)

# %% [markdown]
# Suppression de la colonne merge :

# %%
df.drop(columns=['_merge'],inplace=True)

# %% [markdown]
# Fusion de df et de PoliticalStability :

# %%
df = df.merge(PoliticalStability,
              how='outer',
              on='Country',
              indicator=True)

# %%
df['_merge'].value_counts()
# Out:
# both          183222
# left_only        108
# right_only         0
# Name: _merge, dtype: int64

# %% [markdown]
# Suppression de la colonne merge :

# %%
df.drop(columns=['_merge'],inplace=True)

# %% [markdown]
# Fusion de df et de Population :

# %%
df = df.merge(Population,
              how='outer',
              on='Country',
              indicator=True)

# %%
df['_merge'].value_counts()
# Out:
# both          10369134
# right_only           0
# left_only            0
# Name: _merge, dtype: int64

# %% [markdown]
# Vérification validée.

# %% [markdown]
# Suppression de la colonne merge :

# %%
df.drop(columns=['_merge'],inplace=True)

# %% [markdown]
# # <a name="C7"> Correspondance df & RegionCountry </a>

# %%
RegionCountry.head()
# Out:
#   REGION (DISPLAY) COUNTRY (DISPLAY)
# 0           Europe           Albania
# 1           Europe           Andorra
# 2           Europe           Armenia
# 3          Oceania         Australia
# 4           Europe           Austria

# %% [markdown]
# Il faut renommer la colonne 'COUNTRY (DISPLAY)' en 'Country' pour la fusion des données.

# %%
RegionCountry.rename(columns={"COUNTRY (DISPLAY)":"Country"}, inplace=True)

# %% [markdown]
# Vérification :

# %%
RegionCountry.head()
# Out:
#   REGION (DISPLAY)    Country
# 0           Europe    Albania
# 1           Europe    Andorra
# 2           Europe    Armenia
# 3          Oceania  Australia
# 4           Europe    Austria

# %% [markdown]
# Fusion de df et de RegionCountry :

# %%
df = df.merge(RegionCountry,
              how='outer',
              on='Country',
              indicator=True)

# %%
df['_merge'].value_counts()
# Out:
# both          10369134
# right_only           0
# left_only            0
# Name: _merge, dtype: int64

# %% [markdown]
# Toutes les entrées 'Country' correspondent.

# %% [markdown]
# # <a name="C8"> Fusion des datsets après nettoyage </a>

# %% [markdown]
# ## <a name="C9"> Fusion WaterServices & Mortality </a>

# %% [markdown]
# Analyses des colonnes sur lesquelles fusionner :

# %%
BasicAndSafelyManagedDrinkingWaterServices.head()
# Out:
#    Year      Country Granularity  \
# 0  2000  Afghanistan       Rural
# 1  2000  Afghanistan       Total
# 2  2000  Afghanistan       Urban
# 3  2000      Albania       Rural
# 4  2000      Albania       Total
#
#    Population using at least basic drinking-water services (%)  \
# 0                                           21.61913
# 1                                           27.77190
# 2                                           49.48745
# 3                                           81.78472
# 4                                           87.86662
#
#    Population using safely managed drinking-water services (%)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           49.29324

# %%
MortalityRateAttributedToWater.head()
# Out:
#     Year              Country Granularity  \
# 2   2016          Afghanistan       Total
# 5   2016              Albania       Total
# 8   2016              Algeria       Total
# 11  2016               Angola       Total
# 14  2016  Antigua and Barbuda       Total
#
#     Mortality rate attributed to exposure to unsafe WASH services  WASH deaths
# 2                                            13.92067               4824.35300
# 5                                             0.16641                  4.86975
# 8                                             1.86723                758.21000
# 11                                           48.81467              14065.20000
# 14                                            0.11403                  0.11513

# %%
temp_df = pd.pivot_table(MortalityRateAttributedToWater,
                         values=['WASH deaths'],
                         aggfunc='sum',
                         index='Granularity')
temp_df
# Out:
#               WASH deaths
# Granularity
# Total        870365.88011

# %% [markdown]
# Fusion sur les colonnes Country, year et Granularity :

# %%
df = BasicAndSafelyManagedDrinkingWaterServices.merge(MortalityRateAttributedToWater,
                                                      how='outer',
                                                      on=['Country','Year','Granularity'],
                                                      indicator=True)

# %% [markdown]
# Vérification de la fusion

# %%
df['_merge'].value_counts()
# Out:
# left_only     10293
# both            183
# right_only        0
# Name: _merge, dtype: int64

# %% [markdown]
# 183 lignes ont une correspondance. Nombre de lignes du dataset MortalityRateAttributedToWater :

# %%
len(MortalityRateAttributedToWater)
# Out:
# 183

# %% [markdown]
# Toutes les données ont été fusionnées. Vérification de la fusion en filtrant sur l'année 2016, la granularité Total et l'indicateur _merge à 'both'.
#
# On doit trouver 183 lignes pour être sur que ça ait été fusionné sur l'année 2016 et la granularité Total :

# %%
temp_df = df[(df['Year'] == 2016) & (df['Granularity'] == 'Total') & (df['_merge'] == 'both')]
print('Nombre de lignes :',len(temp_df))
# Out:
# Nombre de lignes : 183

# %%
temp_df
# Out:
#       Year                                            Country Granularity  \
# 9313  2016                                        Afghanistan       Total
# 9316  2016                                            Albania       Total
# 9319  2016                                            Algeria       Total
# 9325  2016                                             Angola       Total
# 9328  2016                                Antigua and Barbuda       Total
# 9331  2016                                          Argentina       Total
# 9334  2016                                            Armenia       Total
# 9337  2016                                          Australia       Total
# 9340  2016                                            Austria       Total
# 9343  2016                                         Azerbaijan       Total
# 9346  2016                                            Bahamas       Total
# 9349  2016                                            Bahrain       Total
# 9352  2016                                         Bangladesh       Total
# 9355  2016                                           Barbados       Total
# 9358  2016                                            Belarus       Total
# 9361  2016                                            Belgium       Total
# 9364  2016                                             Belize       Total
# 9367  2016                                              Benin       Total
# 9370  2016                                             Bhutan       Total
# 9373  2016                   Bolivia (Plurinational State of)       Total
# 9376  2016                             Bosnia and Herzegovina       Total
# 9379  2016                                           Botswana       Total
# 9382  2016                                             Brazil       Total
# 9385  2016                                  Brunei Darussalam       Total
# 9388  2016                                           Bulgaria       Total
# 9391  2016                                       Burkina Faso       Total
# 9394  2016                                            Burundi       Total
# 9397  2016                                         Cabo Verde       Total
# 9400  2016                                           Cambodia       Total
# 9403  2016                                           Cameroon       Total
# 9406  2016                                             Canada       Total
# 9409  2016                           Central African Republic       Total
# 9412  2016                                               Chad       Total
# 9415  2016                                              Chile       Total
# 9418  2016                                              China       Total
# 9421  2016                                           Colombia       Total
# 9424  2016                                            Comoros       Total
# 9427  2016                                              Congo       Total
# 9433  2016                                         Costa Rica       Total
# 9436  2016                                            Croatia       Total
# 9832                                           41.63327
# 9835                                            1.42545
# 9838                                            0.14189
# 9841                                            1.01527
# 9844                                            0.29570
# 9847                                            3.97765
# 9853                                           31.55895
# 9856                                            0.26862
# 9859                                            0.02912
# 9862                                            0.19720
# 9865                                           38.40323
# 9868                                            0.23153
# 9871                                            0.36017
# 9874                                            0.44151
# 9877                                           10.41773
# 9880                                            1.39030
# 9883                                            1.62080
# 9886                                           10.20328
# 9889                                           34.91273
# 9892                                           24.55074
#
#        WASH deaths _merge
# 9313    4824.35300   both
# 9316       4.86975   both
# 9319     758.21000   both
# 9325   14065.20000   both
# 9328       0.11513   both
# 9331     159.14110   both
# 9334       5.17336   both
# 9337      23.01346   both
# 9340      10.78108   both
# 9343     108.91280   both
# 9346       0.26811   both
# 9349       0.56435   both
# 9352   19464.03000   both
# 9355       0.46915   both
# 9358       4.89667   both
# 9361      32.00647   both
# 9364       3.54188   both
# 9367    6494.03400   both
# 9370      31.50916   both
# 9373     607.26450   both
# 9376       2.76853   both
# 9379     264.78070   both
# 9382    2174.62300   both
# 9385       0.19128   both
# 9388       9.18815   both
# 9391    9256.32500   both
# 9394    6882.90100   both
# 9397      22.32021   both
# 9400    1019.87700   both
# 9403   10583.47000   both
# 9406     133.52630   both
# 9409    3772.78400   both
# 9412   14603.30000   both
# 9415      36.31498   both
# 9418    8134.22300   both
# 9421     366.41090   both
# 9424     403.66420   both
# 9427    1984.13800   both
# 9433      41.96055   both
# 9436       4.72051   both
# 9439     117.78320   both
# 9442       3.26564   both
# 9445      18.97327   both
# 9448   11174.47000   both
# 9451     344.14450   both
# 9454   47049.52000   both
# 9457      17.45619   both
# 9460     294.82600   both
# 9466     234.85220   both
# 9469     105.21750   both
# 9472    1915.88200   both
# 9475     127.22030   both
# 9478     272.26470   both
# 9481    2257.55600   both
# 9484       0.08229   both
# 9487     374.63070   both
# 9490   44713.33000   both
# 9493      25.95353   both
# 9496       1.99014   both
# 9499     171.77870   both
# 9502     407.42950   both
# 9505     604.60970   both
# 9508       7.05726   both
# 9511     480.43470   both
# 9514    5312.96700   both
# 9517       4.14944   both
# 9520       0.36792   both
# 9523    1043.89500   both
# 9526    5532.78400   both
# 9529     640.44080   both
# 9532      28.21598   both
# 9535    2580.78600   both
# 9538     329.78520   both
# 9541      23.39143   both
# 9544       0.34426   both
# 9547  246087.90000   both
# 9550   18426.38000   both
# 9553     790.35850   both
# 9556    1129.00500   both
# 9559       3.50464   both
# 9562      20.21871   both
# 9565      81.52759   both
# 9568      17.68140   both
# 9571     212.96280   both
# 9574      59.22872   both
# 9577      68.91383   both
# 9580   24790.32000   both
# 9583      19.05509   both
# 9586       0.50324   both
# 9589      46.21274   both
# 9592     764.55440   both
# 9595       0.40592   both
# 9598      47.25737   both
# 9601     977.54310   both
# 9604    1916.72900   both
# 9607      36.67053   both
# 9610       2.34934   both
# 9613       0.27921   both
# 9616    7526.03900   both
# 9619    5118.16300   both
# 9622     130.98340   both
# 9625       1.30830   both
# 9628   12726.20000   both
# 9631       0.14329   both
# 9637    1658.88200   both
# 9640       7.42695   both
# 9643    1346.23700   both
# 9646       3.74615   both
# 9652      39.01429   both
# 9655       0.15999   both
# 9658     671.39730   both
# 9661    7965.31000   both
# 9664    6673.80500   both
# 9667     454.21270   both
# 9673    5747.14900   both
# 9676      40.92825   both
# 9679       6.79392   both
# 9682     138.02320   both
# 9685   14639.56000   both
# 9688  127641.30000   both
# 9694      11.11950   both
# 9697       2.01467   both
# 9700   37847.05000   both
# 9706      76.49982   both
# 9709    1318.64200   both
# 9712      98.49413   both
# 9715     405.70230   both
# 9718    4332.10500   both
# 9721      34.67636   both
# 9724      15.86048   both
# 9727       0.20829   both
# 9730     917.09530   both
# 9733       3.89474   both
# 9736       1.54705   both
# 9739      71.66723   both
# 9742     150.79380   both
# 9745    2305.97600   both
# 9751       1.11909   both
# 9754       1.46129   both
# 9757       2.90513   both
# 9763      22.71185   both
# 9766      29.77708   both
# 9769    3678.63900   both
# 9772      64.98421   both
# 9775       0.15963   both
# 9778    6012.55000   both
# 9781       3.71719   both
# 9784       2.43565   both
# 9787       0.43939   both
# 9790      37.01826   both
# 9793   12395.83000   both
# 9796    7656.67200   both
# 9799    7740.42000   both
# 9802      70.36836   both
# 9805     247.50770   both
# 9808    6855.94100   both
# 9811      11.20705   both
# 9814      21.16900   both
# 9817      11.58101   both
# 9820     675.54950   both
# 9823     235.88540   both
# 9826    2414.71700   both
# 9829     125.76670   both
# 9832    3166.78000   both
# 9835       1.52692   both
# 9838       1.93681   both
# 9841     115.77420   both
# 9844     235.11920   both
# 9847     225.23610   both
# 9853   13093.17000   both
# 9856     119.37170   both
# 9859       2.69967   both
# 9862     129.73470   both
# 9865   21341.52000   both
# 9868     745.97610   both
# 9871      12.40418   both
# 9874     138.83980   both
# 9877      28.17007   both
# 9880     438.89230   both
# 9883    1532.77700   both
# 9886    2814.49500   both
# 9889    5792.50400   both
# 9892    3965.03300   both

# %% [markdown]
# Vérification validée.

# %% [markdown]
# Suppression de la colonne _merge

# %%
df.drop('_merge', inplace=True, axis=1)

# %% [markdown]
# Vérification de la suppression

# %%
df.head()
# Out:
#    Year      Country Granularity  \
# 0  2000  Afghanistan       Rural
# 1  2000  Afghanistan       Total
# 2  2000  Afghanistan       Urban
# 3  2000      Albania       Rural
# 4  2000      Albania       Total
#
#    Population using at least basic drinking-water services (%)  \
# 0                                           21.61913
# 1                                           27.77190
# 2                                           49.48745
# 3                                           81.78472
# 4                                           87.86662
#
#    Population using safely managed drinking-water services (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           49.29324
#
#    Mortality rate attributed to exposure to unsafe WASH services  WASH deaths
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN

# %% [markdown]
# ## <a name="C10"> Fusion df & Political Stability </a>

# %% [markdown]
# Analyse des colonnes de PoliticalStability pour savoir sur quelles colonnes fusionner :

# %%
PoliticalStability.head()
# Out:
#        Country  Year  Political_Stability Granularity
# 0  Afghanistan  2000                -2.44       Total
# 1  Afghanistan  2002                -2.04       Total
# 2  Afghanistan  2003                -2.20       Total
# 3  Afghanistan  2004                -2.30       Total
# 4  Afghanistan  2005                -2.07       Total

# %% [markdown]
# Il faut fusionner sur Country, Year et Granularity.

# %% [markdown]
# Recherche des granularités présentes dans Political Stability :

# %%
PoliticalStability['Granularity'].value_counts()
# Out:
# Total    3393
# Name: Granularity, dtype: int64

# %% [markdown]
# Il n'y a que la granularité Total.

# %% [markdown]
# Fusion des datasets :

# %%
df1 = df.merge(PoliticalStability,
              how='outer',
              on=['Country','Year','Granularity'],
              indicator=True)

# %% [markdown]
# Vérification de la fusion :

# %%
df1['_merge'].value_counts()
# Out:
# left_only     7273
# both          3203
# right_only     190
# Name: _merge, dtype: int64

# %%
right_only = df1[df1['_merge'] == 'right_only']
right_only.head(20)
# Out:
#        Year              Country Granularity  \
# 10476  2018          Afghanistan       Total
# 10477  2018              Albania       Total
# 10478  2018              Algeria       Total
# 10479  2018              Andorra       Total
# 10480  2018               Angola       Total
# 10481  2018  Antigua and Barbuda       Total
# 10482  2018            Argentina       Total
# 10483  2018              Armenia       Total
# 10484  2018            Australia       Total
# 10485  2018              Austria       Total
# 10486  2018           Azerbaijan       Total
# 10487  2018              Bahamas       Total
# 10488  2018              Bahrain       Total
# 10489  2018           Bangladesh       Total
# 10490  2018             Barbados       Total
# 10491  2018              Belarus       Total
# 10492  2018              Belgium       Total
# 10493  2018               Belize       Total
# 10494  2018                Benin       Total
# 10495  2018               Bhutan       Total
#
#        Population using at least basic drinking-water services (%)  \
# 10476                                                NaN
# 10477                                                NaN
# 10478                                                NaN
# 10479                                                NaN
# 10480                                                NaN
# 10481                                                NaN
# 10482                                                NaN
# 10483                                                NaN
# 10484                                                NaN
# 10485                                                NaN
# 10486                                                NaN
# 10487                                                NaN
# 10488                                                NaN
# 10489                                                NaN
# 10490                                                NaN
# 10491                                                NaN
# 10492                                                NaN
# 10493                                                NaN
# 10494                                                NaN
# 10495                                                NaN
#
#        Population using safely managed drinking-water services (%)  \
# 10476                                                NaN
# 10477                                                NaN
# 10478                                                NaN
# 10479                                                NaN
# 10480                                                NaN
# 10481                                                NaN
# 10482                                                NaN
# 10483                                                NaN
# 10484                                                NaN
# 10485                                                NaN
# 10486                                                NaN
# 10487                                                NaN
# 10488                                                NaN
# 10489                                                NaN
# 10490                                                NaN
# 10491                                                NaN
# 10492                                                NaN
# 10493                                                NaN
# 10494                                                NaN
# 10495                                                NaN
#
#        Mortality rate attributed to exposure to unsafe WASH services  \
# 10476                                                NaN
# 10477                                                NaN
# 10478                                                NaN
# 10479                                                NaN
# 10480                                                NaN
# 10481                                                NaN
# 10482                                                NaN
# 10483                                                NaN
# 10484                                                NaN
# 10485                                                NaN
# 10486                                                NaN
# 10487                                                NaN
# 10488                                                NaN
# 10489                                                NaN
# 10490                                                NaN
# 10491                                                NaN
# 10492                                                NaN
# 10493                                                NaN
# 10494                                                NaN
# 10495                                                NaN
#
#        WASH deaths  Political_Stability      _merge
# 10476          NaN                -2.75  right_only
# 10477          NaN                 0.38  right_only
# 10478          NaN                -0.79  right_only
# 10479          NaN                 1.43  right_only
# 10480          NaN                -0.32  right_only
# 10481          NaN                 0.73  right_only
# 10482          NaN                 0.02  right_only
# 10483          NaN                -0.42  right_only
# 10484          NaN                 0.98  right_only
# 10485          NaN                 0.92  right_only
# 10486          NaN                -0.70  right_only
# 10487          NaN                 0.87  right_only
# 10488          NaN                -0.84  right_only
# 10489          NaN                -1.03  right_only
# 10490          NaN                 0.92  right_only
# 10491          NaN                 0.35  right_only
# 10492          NaN                 0.41  right_only
# 10493          NaN                 0.02  right_only
# 10494          NaN                -0.13  right_only
# 10495          NaN                 1.10  right_only

# %%
right_only['Year'].value_counts()
# Out:
# 2018    190
# Name: Year, dtype: int64

# %% [markdown]
# Pas de fusion sur l'année 2018. Y'a-t-il une année 2018 dans df ?

# %%
df['Year'].value_counts().sort_index()
# Out:
# 2000    582
# 2001    582
# 2002    582
# 2003    582
# 2004    582
# 2005    582
# 2006    582
# 2007    582
# 2008    582
# 2009    582
# 2010    582
# 2011    582
# 2012    582
# 2013    582
# 2014    582
# 2015    582
# 2016    582
# 2017    582
# Name: Year, dtype: int64

# %% [markdown]
# Non, les right_only sont donc justifiés.

# %% [markdown]
# Il y a 3393 lignes dans le dataset PoliticalStability. 3203 lignes ont été fusionnées et 190 non (année 2018 manquante dans df). Toutes les lignes ont-elles été vérifiées ?

# %%
3203+190
# Out:
# 3393

# %% [markdown]
# Oui.
#
# Vérification de la fusion df-PoliticalStability validée.

# %%
df1.drop(columns=['_merge'],inplace=True)

# %% [markdown]
# ## <a name="C11"> Fusion df & Population </a>

# %% [markdown]
# Lecture des colonnes de Population pour savoir sur quelles colonnes fusionner :

# %%
Population.head()
# Out:
#        Country Granularity  Year  Population
# 0  Afghanistan       Total  2000   20779.953
# 3  Afghanistan       Rural  2000   15657.474
# 4  Afghanistan       Urban  2000    4436.282
# 5  Afghanistan       Total  2001   21606.988
# 8  Afghanistan       Rural  2001   16318.324

# %% [markdown]
# Il faut fusionner sur Country, Year et Granularity.
#
# Recherche des granularités présentes dans Population :

# %%
Population['Granularity'].value_counts()
# Out:
# Urban    3650
# Rural    3650
# Total    3650
# Name: Granularity, dtype: int64

# %% [markdown]
# Fusion des datasets :

# %%
df2 = df1.merge(Population,
              how='outer',
              on=['Country','Year','Granularity'],
              indicator=True)

# %% [markdown]
# Vérification de la fusion :

# %%
df2['_merge'].value_counts()
# Out:
# both          10558
# right_only      392
# left_only       108
# Name: _merge, dtype: int64

# %%
right_only = df2[df2['_merge'] == 'right_only']
right_only.head()
# Out:
#        Year      Country Granularity  \
# 10666  2018  Afghanistan       Rural
# 10667  2018  Afghanistan       Urban
# 10668  2018      Albania       Rural
# 10669  2018      Albania       Urban
# 10670  2018      Algeria       Rural
#
#        Population using at least basic drinking-water services (%)  \
# 10666                                                NaN
# 10667                                                NaN
# 10668                                                NaN
# 10669                                                NaN
# 10670                                                NaN
#
#        Population using safely managed drinking-water services (%)  \
# 10666                                                NaN
# 10667                                                NaN
# 10668                                                NaN
# 10669                                                NaN
# 10670                                                NaN
#
#        Mortality rate attributed to exposure to unsafe WASH services  \
# 10666                                                NaN
# 10667                                                NaN
# 10668                                                NaN
# 10669                                                NaN
# 10670                                                NaN
#
#        WASH deaths  Political_Stability  Population      _merge
# 10666          NaN                  NaN   27099.874  right_only
# 10667          NaN                  NaN    9273.302  right_only
# 10668          NaN                  NaN    1164.388  right_only
# 10669          NaN                  NaN    1769.975  right_only
# 10670          NaN                  NaN   11498.038  right_only

# %% [markdown]
# Données de 2018 ?

# %%
right_only['Year'].value_counts()
# Out:
# 2018    392
# Name: Year, dtype: int64

# %% [markdown]
# Le dataset df1 ne contient, pour l'année 2018, que la granularité Total puisque :
# - df (WaterServices + Mortality) n'a pas de données sur 2018
# - PoliticalStability a des données sur 2018 sur la granularité Total
#
# On s'attend donc à ne trouver que les granularités Rural et Urban sur right_only.

# %%
right_only['Granularity'].value_counts()
# Out:
# Rural    194
# Urban    194
# Total      4
# Name: Granularity, dtype: int64

# %% [markdown]
# Affichage des granularités Total :

# %%
right_only[right_only['Granularity'] == 'Total']
# Out:
#        Year       Country Granularity  \
# 10744  2018  Cook Islands       Total
# 10891  2018        Monaco       Total
# 10920  2018          Niue       Total
# 10967  2018    San Marino       Total
#
#        Population using at least basic drinking-water services (%)  \
# 10744                                                NaN
# 10891                                                NaN
# 10920                                                NaN
# 10967                                                NaN
#
#        Population using safely managed drinking-water services (%)  \
# 10744                                                NaN
# 10891                                                NaN
# 10920                                                NaN
# 10967                                                NaN
#
#        Mortality rate attributed to exposure to unsafe WASH services  \
# 10744                                                NaN
# 10891                                                NaN
# 10920                                                NaN
# 10967                                                NaN
#
#        WASH deaths  Political_Stability  Population      _merge
# 10744          NaN                  NaN      17.518  right_only
# 10891          NaN                  NaN      38.682  right_only
# 10920          NaN                  NaN       1.620  right_only
# 10967          NaN                  NaN      33.785  right_only

# %% [markdown]
# Hypothèse : les pays dans right_only n'existent pas dans PoliticalStability, au moins pour l'année 2018.
#
# Vérification :

# %%
countries = right_only[right_only['Granularity'] == 'Total']
countries_list = countries['Country']
countries_list
# Out:
# 10744    Cook Islands
# 10891          Monaco
# 10920            Niue
# 10967      San Marino
# Name: Country, dtype: object

# %%
type(countries_list)
# Out:
# pandas.core.series.Series

# %%
for i in countries_list :
    print(PoliticalStability[PoliticalStability['Country'] == i])
# Out:
#           Country  Year  Political_Stability Granularity
# 789  Cook Islands  2009                 1.14       Total
# 790  Cook Islands  2010                 1.32       Total
# Empty DataFrame
# Columns: [Country, Year, Political_Stability, Granularity]
# Index: []
#      Country  Year  Political_Stability Granularity
# 2318    Niue  2009                 1.14       Total
# 2319    Niue  2010                 1.32       Total
# Empty DataFrame
# Columns: [Country, Year, Political_Stability, Granularity]
# Index: []

# %% [markdown]
# Ces pays n'ont pas de données pour l'année 2018, ce qui explique qu'il n'y ait pas de fusion.
#
# Vérification right_only validée.

# %% [markdown]
# Nombre de lignes de Population :

# %%
len(Population)
# Out:
# 10950

# %% [markdown]
# Résultat de la fusion df1 + Population

# %%
df2['_merge'].value_counts()
# Out:
# both          10558
# right_only      392
# left_only       108
# Name: _merge, dtype: int64

# %% [markdown]
# Si les lignes avec indicateurs both + right_only = 10950, toutes les lignes auront été vérifiées.

# %%
392+10558
# Out:
# 10950

# %% [markdown]
# Fusion df1 + Population validée.

# %% [markdown]
# Suppression colonne _merge :

# %%
df2.drop(columns = '_merge', inplace=True)

# %% [markdown]
# ## <a name="C12"> Fusion df2 & RegionCountry </a>

# %% [markdown]
# Affichage des colonnes de RegionCountry pour savoir sur quelles colonnes fusionner :

# %%
RegionCountry.head()
# Out:
#   REGION (DISPLAY)    Country
# 0           Europe    Albania
# 1           Europe    Andorra
# 2           Europe    Armenia
# 3          Oceania  Australia
# 4           Europe    Austria

# %% [markdown]
# Fusion sur Country :

# %%
df3 = df2.merge(RegionCountry,
              how='outer',
              on='Country',
              indicator=True)

# %% [markdown]
# Vérification de la fusion :

# %%
df3['_merge'].value_counts()
# Out:
# both          11058
# right_only        0
# left_only         0
# Name: _merge, dtype: int64

# %% [markdown]
# Fusion validée

# %%
df3.drop(columns = '_merge', inplace=True)

# %%
df3.head(50)
# Out:
#     Year      Country Granularity  \
# 0   2000  Afghanistan       Rural
# 1   2000  Afghanistan       Total
# 2   2000  Afghanistan       Urban
# 3   2001  Afghanistan       Rural
# 4   2001  Afghanistan       Total
# 5   2001  Afghanistan       Urban
# 6   2002  Afghanistan       Rural
# 7   2002  Afghanistan       Total
# 8   2002  Afghanistan       Urban
# 9   2003  Afghanistan       Rural
# 10  2003  Afghanistan       Total
# 11  2003  Afghanistan       Urban
# 12  2004  Afghanistan       Rural
# 13  2004  Afghanistan       Total
# 14  2004  Afghanistan       Urban
# 15  2005  Afghanistan       Rural
# 16  2005  Afghanistan       Total
# 17  2005  Afghanistan       Urban
# 18  2006  Afghanistan       Rural
# 19  2006  Afghanistan       Total
# 20  2006  Afghanistan       Urban
# 21  2007  Afghanistan       Rural
# 22  2007  Afghanistan       Total
# 23  2007  Afghanistan       Urban
# 24  2008  Afghanistan       Rural
# 25  2008  Afghanistan       Total
# 26  2008  Afghanistan       Urban
# 27  2009  Afghanistan       Rural
# 28  2009  Afghanistan       Total
# 29  2009  Afghanistan       Urban
# 30  2010  Afghanistan       Rural
# 31  2010  Afghanistan       Total
# 32  2010  Afghanistan       Urban
# 33  2011  Afghanistan       Rural
# 34  2011  Afghanistan       Total
# 35  2011  Afghanistan       Urban
# 36  2012  Afghanistan       Rural
# 37  2012  Afghanistan       Total
# 38  2012  Afghanistan       Urban
# 39  2013  Afghanistan       Rural
# 40  2013  Afghanistan       Total
# 41  2013  Afghanistan       Urban
# 42  2014  Afghanistan       Rural
# 43  2014  Afghanistan       Total
# 44  2014  Afghanistan       Urban
# 45  2015  Afghanistan       Rural
# 46  2015  Afghanistan       Total
# 47  2015  Afghanistan       Urban
# 48  2016  Afghanistan       Rural
# 49  2016  Afghanistan       Total
#
#     Population using at least basic drinking-water services (%)  \
# 0                                            21.61913
# 1                                            27.77190
# 2                                            49.48745
# 3                                            21.61913
# 4                                            27.79726
# 5                                            49.48745
# 6                                            23.59988
# 7                                            29.90076
# 8                                            51.90447
# 9                                            25.58063
# 10                                           32.00507
# 11                                           54.32149
# 12                                           27.56138
# 13                                           34.12623
# 14                                           56.73851
# 15                                           29.54213
# 16                                           36.26526
# 17                                           59.15553
# 18                                           31.52288
# 19                                           38.40636
# %%
df3.to_csv('df.csv', index=False)

# %%
df4 = df3

# %% [markdown]
# # <a name="C14.2"> Ajout de la colonne Urban population rate </a>

# %% [markdown]
# Stockage granularité Total :

# %%
total = df4[df4['Granularity'] == 'Total']
total.head()
# Out:
#     Year      Country Granularity  \
# 1   2000  Afghanistan       Total
# 4   2001  Afghanistan       Total
# 7   2002  Afghanistan       Total
# 10  2003  Afghanistan       Total
# 13  2004  Afghanistan       Total
#
#     Population using at least basic drinking-water services (%)  \
# 1                                            27.77190
# 4                                            27.79726
# 7                                            29.90076
# 10                                           32.00507
# 13                                           34.12623
#
#     Population using safely managed drinking-water services (%)  \
# 1                                                 NaN
# 4                                                 NaN
# 7                                                 NaN
# 10                                                NaN
# 13                                                NaN
#
#     Mortality rate attributed to exposure to unsafe WASH services  \
# 1                                                 NaN
# 4                                                 NaN
# 7                                                 NaN
# 10                                                NaN
# 13                                                NaN
#
#     WASH deaths  Political_Stability  Population REGION (DISPLAY)
# 1           NaN                -2.44   20779.953             Asia
# 4           NaN                  NaN   21606.988             Asia
# 7           NaN                -2.04   22600.770             Asia
# 10          NaN                -2.20   23680.871             Asia
# 13          NaN                -2.30   24726.684             Asia

# %% [markdown]
# Stockage granularité Urban :

# %%
urban = df4[df4['Granularity'] == 'Urban']
urban.head()
# Out:
#     Year      Country Granularity  \
# 2   2000  Afghanistan       Urban
# 5   2001  Afghanistan       Urban
# 8   2002  Afghanistan       Urban
# 11  2003  Afghanistan       Urban
# 14  2004  Afghanistan       Urban
#
#     Population using at least basic drinking-water services (%)  \
# 2                                            49.48745
# 5                                            49.48745
# 8                                            51.90447
# 11                                           54.32149
# 14                                           56.73851
#
#     Population using safely managed drinking-water services (%)  \
# 2                                                 NaN
# 5                                                 NaN
# 8                                                 NaN
# 11                                                NaN
# 14                                                NaN
#
#     Mortality rate attributed to exposure to unsafe WASH services  \
# 2                                                 NaN
# 5                                                 NaN
# 8                                                 NaN
# 11                                                NaN
# 14                                                NaN
#
#     WASH deaths  Political_Stability  Population REGION (DISPLAY)
# 2           NaN                  NaN    4436.282             Asia
# 5           NaN                  NaN    4648.139             Asia
# 8           NaN                  NaN    4893.013             Asia
# 11          NaN                  NaN    5155.788             Asia
# 14          NaN                  NaN    5426.872             Asia

# %%
df5 = df4.merge(urban[['Country','Year','Population']],
                  how='left',
                  on=['Country','Year'],
                  indicator=True)
df5['_merge'].value_counts()
# Out:
# both          11058
# right_only        0
# left_only         0
# Name: _merge, dtype: int64

# %%
df5.head()
# Out:
#    Year      Country Granularity  \
# 0  2000  Afghanistan       Rural
# 1  2000  Afghanistan       Total
# 2  2000  Afghanistan       Urban
# 3  2001  Afghanistan       Rural
# 4  2001  Afghanistan       Total
#
#    Population using at least basic drinking-water services (%)  \
# 0                                           21.61913
# 1                                           27.77190
# 2                                           49.48745
# 3                                           21.61913
# 4                                           27.79726
#
#    Population using safely managed drinking-water services (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Mortality rate attributed to exposure to unsafe WASH services  WASH deaths  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
#
#    Political_Stability  Population_x REGION (DISPLAY)  Population_y _merge
# 0                  NaN     15657.474             Asia      4436.282   both
# 1                -2.44     20779.953             Asia      4436.282   both
# 2                  NaN      4436.282             Asia      4436.282   both
# 3                  NaN     16318.324             Asia      4648.139   both
# 4                  NaN     21606.988             Asia      4648.139   both

# %%
df5.drop(columns='_merge',inplace=True)

# %%
df5.head()
# Out:
#    Year      Country Granularity  \
# 0  2000  Afghanistan       Rural
# 1  2000  Afghanistan       Total
# 2  2000  Afghanistan       Urban
# 3  2001  Afghanistan       Rural
# 4  2001  Afghanistan       Total
#
#    Population using at least basic drinking-water services (%)  \
# 0                                           21.61913
# 1                                           27.77190
# 2                                           49.48745
# 3                                           21.61913
# 4                                           27.79726
#
#    Population using safely managed drinking-water services (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Mortality rate attributed to exposure to unsafe WASH services  WASH deaths  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
#
#    Political_Stability  Population_x REGION (DISPLAY)  Population_y
# 0                  NaN     15657.474             Asia      4436.282
# 1                -2.44     20779.953             Asia      4436.282
# 2                  NaN      4436.282             Asia      4436.282
# 3                  NaN     16318.324             Asia      4648.139
# 4                  NaN     21606.988             Asia      4648.139

# %%
df5.rename(columns={"Population_x": "Population","Population_y": "Urban population"},inplace=True)

# %%
df5.head()
# Out:
#    Year      Country Granularity  \
# 0  2000  Afghanistan       Rural
# 1  2000  Afghanistan       Total
# 2  2000  Afghanistan       Urban
# 3  2001  Afghanistan       Rural
# 4  2001  Afghanistan       Total
#
#    Population using at least basic drinking-water services (%)  \
# 0                                           21.61913
# 1                                           27.77190
# 2                                           49.48745
# 3                                           21.61913
# 4                                           27.79726
#
#    Population using safely managed drinking-water services (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Mortality rate attributed to exposure to unsafe WASH services  WASH deaths  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
#
#    Political_Stability  Population REGION (DISPLAY)  Urban population
# 0                  NaN   15657.474             Asia          4436.282
# 1                -2.44   20779.953             Asia          4436.282
# 2                  NaN    4436.282             Asia          4436.282
# 3                  NaN   16318.324             Asia          4648.139
# 4                  NaN   21606.988             Asia          4648.139

# %%
df5.loc[df5['Granularity'] == 'Total', 'Urban population rate'] = \
(df5['Urban population']/df5['Population'])*100

# %%
df5.head()
# Out:
#    Year      Country Granularity  \
# 0  2000  Afghanistan       Rural
# 1  2000  Afghanistan       Total
# 2  2000  Afghanistan       Urban
# 3  2001  Afghanistan       Rural
# 4  2001  Afghanistan       Total
#
#    Population using at least basic drinking-water services (%)  \
# 0                                           21.61913
# 1                                           27.77190
# 2                                           49.48745
# 3                                           21.61913
# 4                                           27.79726
#
#    Population using safely managed drinking-water services (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Mortality rate attributed to exposure to unsafe WASH services  WASH deaths  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
#
#    Political_Stability  Population REGION (DISPLAY)  Urban population  \
# 0                  NaN   15657.474             Asia          4436.282
# 1                -2.44   20779.953             Asia          4436.282
# 2                  NaN    4436.282             Asia          4436.282
# 3                  NaN   16318.324             Asia          4648.139
# 4                  NaN   21606.988             Asia          4648.139
#
#    Urban population rate
# 0                    NaN
# 1              21.348855
# 2                    NaN
# 3                    NaN
# 4              21.512202

# %% [markdown]
# # <a name="C14.5"> Ajout des densités de Population </a>

# %% [markdown]
# ## <a name="C14.51"> Ajout des densités de Population par Pays</a>

# %%
pop_density_country = pd.read_excel('population density Country calculated from World Bank.xlsx', index_col=0)
pop_density_country.head()
# Out:
#           Country Granularity  Population density
# Year
# 2000  Afghanistan       Total           31.829117
# 2001  Afghanistan       Total           33.095904
# 2002  Afghanistan       Total           34.618102
# 2003  Afghanistan       Total           36.272510
# 2004  Afghanistan       Total           37.874413

# %%
df6 = df5.merge(pop_density_country,
                how='left',
                on=['Country','Year','Granularity'],
                indicator=True)

# %%
df6['_merge'].value_counts()
# Out:
# left_only     7421
# both          3637
# right_only       0
# Name: _merge, dtype: int64

# %% [markdown]
# Les granularités Urban et Rural n'ont pas pu être jointées.

# %%
Urban = df6[df6['Granularity'] == 'Urban']
Rural = df6[df6['Granularity'] == 'Rural']
len(Urban)+len(Rural)
# Out:
# 7372

# %% [markdown]
# Sur les 7 421 'left_only', 7 372 lignes justifiées par une granularité Rural ou Urban.
#
# Combien de 'left_only' reste-t-il à justifier ?

# %%
7421-7372
# Out:
# 49

# %%
len(df6[(df6['Granularity'] == 'Total') & (df6['_merge'] == 'left_only')])
# Out:
# 49

# %% [markdown]
# La sélection comprend bien les 49 lignes restant à justifier.

# %%
df6[(df6['Granularity'] == 'Total') & (df6['_merge'] == 'left_only')]
# Out:
#       Year       Country Granularity  \
# 2224  2000  Cook Islands       Total
# 2227  2001  Cook Islands       Total
# 2230  2002  Cook Islands       Total
# 2233  2003  Cook Islands       Total
# 2236  2004  Cook Islands       Total
# 2239  2005  Cook Islands       Total
# 2242  2006  Cook Islands       Total
# 7201          NaN                  NaN       1.661          Oceania
# 7204          NaN                  NaN       1.643          Oceania
# 7207          NaN                  NaN       1.635          Oceania
# 7210          NaN                 1.14       1.628          Oceania
# 7213          NaN                 1.32       1.618          Oceania
# 7216          NaN                  NaN       1.620          Oceania
# 7219          NaN                  NaN       1.610          Oceania
# 7222          NaN                  NaN       1.612          Oceania
# 7225          NaN                  NaN       1.609          Oceania
# 7228          NaN                  NaN       1.619          Oceania
# 7231          NaN                  NaN       1.614          Oceania
# 7234          NaN                  NaN       1.609          Oceania
# 7236          NaN                  NaN       1.620          Oceania
# 9235          NaN                  NaN         NaN           Africa
# 9238          NaN                  NaN         NaN           Africa
# 9241          NaN                  NaN         NaN           Africa
# 9244          NaN                  NaN         NaN           Africa
# 9247          NaN                  NaN         NaN           Africa
# 9250          NaN                  NaN         NaN           Africa
# 9253          NaN                  NaN         NaN           Africa
# 9256          NaN                  NaN         NaN           Africa
# 9259          NaN                  NaN         NaN           Africa
# 9262          NaN                  NaN         NaN           Africa
# 9265          NaN                  NaN         NaN           Africa
#
#       Urban population  Urban population rate  Population density     _merge
# 2224            11.814              65.889571                 NaN  left_only
# 2227            12.258              68.005548                 NaN  left_only
# 2230            12.750              69.755991                 NaN  left_only
# 2233            13.239              71.146819                 NaN  left_only
# 2236            13.684              72.386796                 NaN  left_only
# 2239            13.999              73.393101                 NaN  left_only
# 2242            14.170              74.219568                 NaN  left_only
# 2245            14.140              74.417136                 NaN  left_only
# 2248            13.974              74.258688                 NaN  left_only
# 2251            13.773              74.040426                 NaN  left_only
# 2254            13.585              73.867653                 NaN  left_only
# 2257            13.421              73.762023                 NaN  left_only
# 2260            13.272              73.688302                 NaN  left_only
# 2263            13.142              73.694835                 NaN  left_only
# 2266            13.048              73.755017                 NaN  left_only
# 2269            12.983              73.825770                 NaN  left_only
# 2272            12.968              74.001370                 NaN  left_only
# 2275            13.006              74.290284                 NaN  left_only
# 2277            13.067              74.591848                 NaN  left_only
# 7183             0.628              33.070037                 NaN  left_only
# 7186             0.620              33.441208                 NaN  left_only
# 7189             0.606              33.835846                 NaN  left_only
# 7192             0.602              34.301994                 NaN  left_only
# 7195             0.596              34.752187                 NaN  left_only
# 7198             0.593              35.234700                 NaN  left_only
# 7201             0.593              35.701385                 NaN  left_only
# 7204             0.600              36.518564                 NaN  left_only
# 7207             0.609              37.247706                 NaN  left_only
# 7210             0.620              38.083538                 NaN  left_only
# 7213             0.630              38.936959                 NaN  left_only
# 7216             0.643              39.691358                 NaN  left_only
# 7219             0.653              40.559006                 NaN  left_only
# 7222             0.666              41.315136                 NaN  left_only
# 7225             0.676              42.013673                 NaN  left_only
# 7228             0.693              42.804200                 NaN  left_only
# 7231             0.703              43.556382                 NaN  left_only
# 7234             0.713              44.313238                 NaN  left_only
# 7236             0.727              44.876543                 NaN  left_only
# 9235               NaN                    NaN                 NaN  left_only
# 9238               NaN                    NaN                 NaN  left_only
# 9241               NaN                    NaN                 NaN  left_only
# 9244               NaN                    NaN                 NaN  left_only
# 9247               NaN                    NaN                 NaN  left_only
# 9250               NaN                    NaN                 NaN  left_only
# 9253               NaN                    NaN                 NaN  left_only
# 9256               NaN                    NaN                 NaN  left_only
# 9259               NaN                    NaN                 NaN  left_only
# 9262               NaN                    NaN                 NaN  left_only
# 9265               NaN                    NaN                 NaN  left_only

# %% [markdown]
# Pas de données sur Cook Islands et Inue. Données parcellaires sur Soudan du Sud.
#
# Fusion validée.

# %%
df6.drop(columns='_merge', inplace=True)

# %%
df6 = df6.rename(columns={'Population density':'Population density Country'})

# %%
df6['REGION (DISPLAY)'].value_counts()
# Out:
# Europe      3021
# Africa      3021
# Asia        2109
# Americas    1995
# Oceania      912
# Name: REGION (DISPLAY), dtype: int64

# %% [markdown]
# ## <a name="C14.52"> Ajout des densités de Population par Région</a>

# %% [markdown]
# Données provenant de https://www.populationdata.net/monde/

# %%
# create a list of our conditions
conditions = [
    (df6['REGION (DISPLAY)'] == 'Asia'),
    (df6['REGION (DISPLAY)'] == 'Africa'),
    (df6['REGION (DISPLAY)'] == 'Americas'),
    (df6['REGION (DISPLAY)'] == 'Oceania'),
    (df6['REGION (DISPLAY)'] == 'Europe'),
    ]

# create a list of the values we want to assign for each condition
values = [142.7, 43.25, 24.29, 5.06, 32.32]

# create a new column and use np.select to assign values to it using our lists as arguments
df6['population density region'] = np.select(conditions, values)

# display updated DataFrame
df6['population density region'].value_counts()
# Out:
# 43.25     3021
# 32.32     3021
# 142.70    2109
# 24.29     1995
# 5.06       912
# Name: population density region, dtype: int64

# %%
df6.head()
# Out:
#    Year      Country Granularity  \
# 0  2000  Afghanistan       Rural
# 1  2000  Afghanistan       Total
# 2  2000  Afghanistan       Urban
# 3  2001  Afghanistan       Rural
# 4  2001  Afghanistan       Total
#
#    Population using at least basic drinking-water services (%)  \
# 0                                           21.61913
# 1                                           27.77190
# 2                                           49.48745
# 3                                           21.61913
# 4                                           27.79726
#
#    Population using safely managed drinking-water services (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Mortality rate attributed to exposure to unsafe WASH services  WASH deaths  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
#
#    Political_Stability  Population REGION (DISPLAY)  Urban population  \
# 0                  NaN   15657.474             Asia          4436.282
# 1                -2.44   20779.953             Asia          4436.282
# 2                  NaN    4436.282             Asia          4436.282
# 3                  NaN   16318.324             Asia          4648.139
# 4                  NaN   21606.988             Asia          4648.139
#
#    Urban population rate  Population density Country  \
# 0                    NaN                         NaN
# 1              21.348855                   31.829117
# 2                    NaN                         NaN
# 3                    NaN                         NaN
# 4              21.512202                   33.095904
#
#    population density region
# 0                      142.7
# 1                      142.7
# 2                      142.7
# 3                      142.7
# 4                      142.7

# %%
df7 = df6

# %% [markdown]
# ## <a name="C14.53"> Ajout de la densité de Population au niveau Monde</a>

# %%
df7['population density world'] = 50.2

# %%
df7.head()
# Out:
#    Year      Country Granularity  \
# 0  2000  Afghanistan       Rural
# 1  2000  Afghanistan       Total
# 2  2000  Afghanistan       Urban
# 3  2001  Afghanistan       Rural
# 4  2001  Afghanistan       Total
#
#    Population using at least basic drinking-water services (%)  \
# 0                                           21.61913
# 1                                           27.77190
# 2                                           49.48745
# 3                                           21.61913
# 4                                           27.79726
#
#    Population using safely managed drinking-water services (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Mortality rate attributed to exposure to unsafe WASH services  WASH deaths  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
#
# 2011        585633.612              43.038050                  138.330135
# 2012        585633.612                    NaN                         NaN
# 2013        606988.730                    NaN                         NaN
# 2014        606988.730              44.353390                  139.104693
# 2015        606988.730                    NaN                         NaN
# 2016        628350.588                    NaN                         NaN
# 2017        628350.588              45.656200                  139.833098
# 2018        628350.588                    NaN                         NaN
# 2019        650038.030                    NaN                         NaN
# 2020        650038.030              46.968553                  140.551423
# 2021        650038.030                    NaN                         NaN
# 2022        671961.097                    NaN                         NaN
# 2023        671961.097              48.282606                  141.252234
# 2024        671961.097                    NaN                         NaN
# 2025        694170.135                    NaN                         NaN
# 2026        694170.135              49.601200                  141.936072
# 2027        694170.135                    NaN                         NaN
# 2028        715762.326                    NaN                         NaN
# 2029        715762.326              50.859817                  142.713813
# 2030        715762.326                    NaN                         NaN
# 2031        737124.022                    NaN                         NaN
# 2032        737124.022              52.087527                  143.685196
# 2033        737124.022                    NaN                         NaN
# 2034        758533.671                    NaN                         NaN
# 2035        758533.671              53.306331                  144.645433
# 2036        758533.671                    NaN                         NaN
# 2037        779954.516                    NaN                         NaN
# 2038        779954.516              54.516700                  145.560051
# 2039        779954.516                    NaN                         NaN
# 2040        801263.909                    NaN                         NaN
# 2041        801263.909              55.713223                  146.408883
# 2042        801263.909                    NaN                         NaN
# 2043        822422.660                    NaN                         NaN
# 2044        822422.660              56.894434                  147.250303
# 2045        822422.660                    NaN                         NaN
# 2046        843314.783                    NaN                         NaN
# 2047        843314.783              58.054532                  148.144225
# 2048        843314.783                    NaN                         NaN
# 2049        863601.691              59.176027                  148.838644
# 2050        863601.691                    NaN                         NaN
# 2051        863601.691                    NaN                         NaN
#
#       population density region  population density world
# 1995                      142.7                      50.2
# 1996                      142.7                      50.2
# 1997                      142.7                      50.2
# 1998                      142.7                      50.2
# 1999                      142.7                      50.2
# 2000                      142.7                      50.2
# 2001                      142.7                      50.2
# 2002                      142.7                      50.2
# 2003                      142.7                      50.2
# 2004                      142.7                      50.2
# 2005                      142.7                      50.2
# 2006                      142.7                      50.2
# 2007                      142.7                      50.2
# 2008                      142.7                      50.2
# 2009                      142.7                      50.2
# 2010                      142.7                      50.2
# 2011                      142.7                      50.2
# 2012                      142.7                      50.2
# 2013                      142.7                      50.2
# 2014                      142.7                      50.2
# 2015                      142.7                      50.2
# 2016                      142.7                      50.2
# 2017                      142.7                      50.2
# 2018                      142.7                      50.2
# 2019                      142.7                      50.2
# 2020                      142.7                      50.2
# 2021                      142.7                      50.2
# 2022                      142.7                      50.2
# 2023                      142.7                      50.2
# 2024                      142.7                      50.2
# 2025                      142.7                      50.2
# 2026                      142.7                      50.2
# 2027                      142.7                      50.2
# 2028                      142.7                      50.2
# 2029                      142.7                      50.2
# 2030                      142.7                      50.2
# 2031                      142.7                      50.2
# 2032                      142.7                      50.2
# 2033                      142.7                      50.2
# 2034                      142.7                      50.2
# 2035                      142.7                      50.2
# 2036                      142.7                      50.2
# 2037                      142.7                      50.2
# 2038                      142.7                      50.2
# 2039                      142.7                      50.2
# 2040                      142.7                      50.2
# 2041                      142.7                      50.2
# 2042                      142.7                      50.2
# 2043                      142.7                      50.2
# 2044                      142.7                      50.2
# 2045                      142.7                      50.2
# 2046                      142.7                      50.2
# 2047                      142.7                      50.2
# 2048                      142.7                      50.2
# 2049                      142.7                      50.2
# 2050                      142.7                      50.2
# 2051                      142.7                      50.2

# %%
df7.head(50)
# Out:
#     Year      Country Granularity  \
# 0   2000  Afghanistan       Rural
# 1   2000  Afghanistan       Total
# 2   2000  Afghanistan       Urban
# 3   2001  Afghanistan       Rural
# 4   2001  Afghanistan       Total
# 5   2001  Afghanistan       Urban
# 6   2002  Afghanistan       Rural
# 7   2002  Afghanistan       Total
# 8   2002  Afghanistan       Urban
# 9   2003  Afghanistan       Rural
# 10  2003  Afghanistan       Total
# 11  2003  Afghanistan       Urban
# 12  2004  Afghanistan       Rural
# 13  2004  Afghanistan       Total
# 14  2004  Afghanistan       Urban
# 15  2005  Afghanistan       Rural
# 16  2005  Afghanistan       Total
# 17  2005  Afghanistan       Urban
# 18  2006  Afghanistan       Rural
# 19  2006  Afghanistan       Total
# 20  2006  Afghanistan       Urban
# 21  2007  Afghanistan       Rural
# 22  2007  Afghanistan       Total
# 23  2007  Afghanistan       Urban
# 24  2008  Afghanistan       Rural
# 25  2008  Afghanistan       Total
# 26  2008  Afghanistan       Urban
# 27  2009  Afghanistan       Rural
# 28  2009  Afghanistan       Total
# 29  2009  Afghanistan       Urban
# 30  2010  Afghanistan       Rural
# 31  2010  Afghanistan       Total
# 32  2010  Afghanistan       Urban
# 33  2011  Afghanistan       Rural
# 34  2011  Afghanistan       Total
# 35  2011  Afghanistan       Urban
# 36  2012  Afghanistan       Rural
# 37  2012  Afghanistan       Total
# 38  2012  Afghanistan       Urban
# 39  2013  Afghanistan       Rural
# 40  2013  Afghanistan       Total
# 41  2013  Afghanistan       Urban
# 42  2014  Afghanistan       Rural
# 43  2014  Afghanistan       Total
# 44  2014  Afghanistan       Urban
# 45  2015  Afghanistan       Rural
# 46  2015  Afghanistan       Total
# 47  2015  Afghanistan       Urban
# 48  2016  Afghanistan       Rural
# 49  2016  Afghanistan       Total
#
#     Population using at least basic drinking-water services (%)  \
# 0                                            21.61913
# 1                                            27.77190
# 2                                            49.48745
# 3                                            21.61913
# 4                                            27.79726
# 5                                            49.48745
# 6                                            23.59988
# 7                                            29.90076
# 8                                            51.90447
# 9                                            25.58063
# 10                                           32.00507
# 11                                           54.32149
# 12                                           27.56138
# 13                                           34.12623
# 14                                           56.73851
# 15                                           29.54213
# 16                                           36.26526
# 17                                           59.15553
# 18                                           31.52288
# 19                                           38.40636
# 20                                           61.57254
# 21                                           33.73274
# 22                                           40.84418
# 23                                           64.50089
# 24                                           35.96969
# 25                                           43.31506
# 26                                           67.46785
# 27                                           38.23373
# 28                                           45.81909
# 29                                           70.47343
# 30                                           40.52486
# 31                                           48.35636
# 32                                           73.51765
# 33                                           42.84308
# 34                                           50.92731
# 35                                           76.60050
# 36                                           45.18839
# 37                                           53.53170
# 38                                           79.72198
# 39                                           47.56079
# 40                                           56.16964
# 41                                           82.88207
# 42                                           49.96028
# 43                                           58.84123
# 44                                           86.08080
# 45                                           52.38686
# 46                                           61.54693
# 47                                           89.31815
# 48                                           54.84053
# 49                                           64.28648
#
#     Population using safely managed drinking-water services (%)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#
# 8           4893.013                    NaN                         NaN
# 9           5155.788                    NaN                         NaN
# 10          5155.788              21.771953                   36.272510
# 11          5155.788                    NaN                         NaN
# 12          5426.872                    NaN                         NaN
# 13          5426.872              21.947431                   37.874413
# 14          5426.872                    NaN                         NaN
# 15          5691.836                    NaN                         NaN
# 16          5691.836              22.186694                   39.295215
# 17          5691.836                    NaN                         NaN
# 18          5931.478                    NaN                         NaN
# 19          5931.478              22.439629                   40.488095
# 20          5931.478                    NaN                         NaN
# 21          6151.869                    NaN                         NaN
# 22          6151.869              22.700175                   41.510495
# 23          6151.869                    NaN                         NaN
# 24          6364.912                    NaN                         NaN
# 25          6364.912              22.959558                   42.462827
# 26          6364.912                    NaN                         NaN
# 27          6588.738                    NaN                         NaN
# 28          6588.738              23.204020                   43.492948
# 29          6588.738                    NaN                         NaN
# 30          6836.980                    NaN                         NaN
# 31          6836.980              23.425942                   44.704088
# 32          6836.980                    NaN                         NaN
# 33          7114.473                    NaN                         NaN
# 34          7114.473              23.622457                   46.131500
# 35          7114.473                    NaN                         NaN
# 36          7416.295                    NaN                         NaN
# 37          7416.295              23.799639                   47.730567
# 38          7416.295                    NaN                         NaN
# 39          7733.832                    NaN                         NaN
# 40          7733.832              23.966317                   49.428043
# 41          7733.832                    NaN                         NaN
# 42          8054.222                    NaN                         NaN
# 43          8054.222              24.135542                   51.114793
# 44          8054.222                    NaN                         NaN
# 45          8367.571                    NaN                         NaN
# 46          8367.571              24.314719                   52.712072
# 47          8367.571                    NaN                         NaN
# 48          8670.939                    NaN                         NaN
# 49          8670.939              24.505924                   54.196961
#
#     population density region  population density world
# 0                       142.7                      50.2
# 1                       142.7                      50.2
# 2                       142.7                      50.2
# 3                       142.7                      50.2
# 4                       142.7                      50.2
# 5                       142.7                      50.2
# 6                       142.7                      50.2
# 7                       142.7                      50.2
# 8                       142.7                      50.2
# 9                       142.7                      50.2
# 10                      142.7                      50.2
# 11                      142.7                      50.2
# 12                      142.7                      50.2
# 13                      142.7                      50.2
# 14                      142.7                      50.2
# 15                      142.7                      50.2
# 16                      142.7                      50.2
# 17                      142.7                      50.2
# 18                      142.7                      50.2
# 19                      142.7                      50.2
# 20                      142.7                      50.2
# 21                      142.7                      50.2
# 22                      142.7                      50.2
# 23                      142.7                      50.2
# 24                      142.7                      50.2
# 25                      142.7                      50.2
# 26                      142.7                      50.2
# 27                      142.7                      50.2
# 28                      142.7                      50.2
# 29                      142.7                      50.2
# 30                      142.7                      50.2
# 31                      142.7                      50.2
# 32                      142.7                      50.2
# 33                      142.7                      50.2
# 34                      142.7                      50.2
# 35                      142.7                      50.2
# 36                      142.7                      50.2
# 37                      142.7                      50.2
# 38                      142.7                      50.2
# 39                      142.7                      50.2
# 40                      142.7                      50.2
# 41                      142.7                      50.2
# 42                      142.7                      50.2
# 43                      142.7                      50.2
# 44                      142.7                      50.2
# 45                      142.7                      50.2
# 46                      142.7                      50.2
# 47                      142.7                      50.2
# 48                      142.7                      50.2
# 49                      142.7                      50.2
